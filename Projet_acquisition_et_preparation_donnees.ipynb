# %% [markdown]
# #  Acquistion, agrégation et structuration de données

# %% [markdown]
# **Ce projet est à faire en groupe**
#
#
# - G1: Mathieu, Adrien, Elliot
# - G2: Yamine, Chris, Ahmed, Alan
# - G3: Josephe, Arnaud, Guillaume
# - G4: Sébastien, Yann, Pierre, Valentin
# - G5: Alexis, Thomas, Jules
# - G6:
# - G7:
#
# Les personnes absentes le 07/11, contactez-moi.

# %% [markdown]
# ## Consignes

# %% [markdown]
# Le but de cet exercice est de construire un conteneur de données qui contiendra des data sets concernant les **50 films les mieux notés selon [IMDB](https://www.imdb.com/list/ls055386972/) de 2001 à maintentant**.
#
# **Attention** : *Avant de commencer, je vous invite à lire toutes les questions afin d'anticiper les informations qui vous seront demandées et mieux planifier vos traitements*

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Extraction de données

# %% [markdown]
# Commencez par extraire les données dont vous aurez besoin pour répondre à la question posée. Vous pourrez combiner différentes méthodes pour extraires toutes les sources dont vous aurez besoin, comme par exemple:
# - télécharger des data sets accessibles en Open Data à partir de [kaggle](https://www.kaggle.com/datasets?search=imbd)
# - scraper la [page des 250 films les mieux notés d'IMDB](https://www.imdb.com/list/ls055386972/)
# - utiliser des API(s) existantes pour récupérer des informations manquantes [API](https://sites.google.com/magicmakers.fr/teen-python/projets-dexploration/services-web/apis/api-imdb)

# %% [markdown]
# ### Réponse 1

# %% [markdown]
# Affichez dans les cellules ci-dessous les structures de données dans lesquelles vous avez récupéré les informations pertinentes et donnez quelques caractéristiques de chacun de ce(s) data set(s) (par exemple taille, valeurs uniques, min , max ...)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:126.0) Gecko/20100101 Firefox/126.0",
    "Accept-Language":"en-US"
}

class imdbApi:

    def __init__(self) -> None:
        self.__key = "c183e392"
        self.__link = "http://www.omdbapi.com/?apikey="
        pass

    def getFilm(self,name)->list:
        requestApi = "http://www.omdbapi.com/?apikey=" + self.__key+"&t=" + name
        response = requests.get(requestApi)
        film = response.json()
        return film
    
        
class People :
    def __init__(self, name:str, work:str):
        self.__name = name
        self.work = work

    def setName(self, name:str):
        self.__name=name
    
    def getName(self):
        return self.__name

class Film : 
    def __init__(self,title:str) -> None:
        self.__title = title
        self.__img = ""
        self.__year =None
        self.__duration = None
        self.__genre = ""
        self.__actors = []
        self.__director = None
        self.__plot=""
        pass

    def get_image(self):
        return self.__img
    
    def set_image(self, src:str):
        self.__img=src
    
    def get_title(self):
        return self.__title
    
    def get_year(self):
        return self.__year
    
    def get_dureation(self):
        return self.__duration
    
    def set_year(self,year):
        self.__year = int(year)
    
    def set_duration(self, duration):
        self.__duration=duration

    def set_genre(self, genre:str):
        self.__genre = genre
    
    def get_genre(self):
        return self.__genre
    
    def add_actors(self, actor:People):
        self.__actors.append(actor)
    
    def get_actors(self):
        return self.__actors
    
    def set_director(self, director:People):
        self.__director = director
    
    def get_actors(self):
        return self.__director
    
    def set_plot(self, plot):
        self.__plot = plot

    def get_plot(self):
        return self.__plot
    
    def to_dict(self):
        names=[]
        for a in self.__actors:
            names.append(a.getName())
        if self.__director is None:
            director =""
        else:
            director = self.__director.getName()
        return {
            "Image": self.__img,
            "Titre": self.__title,
            "Genre": self.__genre,
            "Année": self.__year,
            "Duration": self.__duration,
            "Description":self.__plot,
            "Réalisateur": director,
            "Acteur": json.dumps(names)
        }

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Filtrage et structuration des données

# %% [markdown]
# Vous allez maintenant filtrer vos données pour vous assurer qu'elles correspondent aux critères fixés dans les consignes et les structures en 3 dataframes distincts décrits ci dessous.
#
# Vous présenterez les variables que vous avez retenues et donnerez un aperçu de leur quantité de valeurs manquantes

# %% [markdown]
# #### Dataframe contenant des informations spécifiques au film :

# %% [markdown]
# Ce dataframe doit contenir à minima une colonne renseignant:
#  - le titre du film
#  - l'année de sa sortie en salle
#  - la durée du film (runtime)
#  - son genre
#  - le nom de son réalisateur (director)
#  - la liste des acteurs principaux
#
# Et en bonus d'autres informations comme:
#  - une description du film
#  - une photo de l'affiche du film

# %% [markdown]
# #### Dataframe contenant des informations concernant la popularité du film :

# %% [markdown]
# Ce dataframe doit contenir à minima une colonne renseignant:
#  - le nombre de votes d'utilisateurs pour ce film (échelle de 1 à 10)
#  - la note moyenne des votes reçus (échelle de 1 à 10)
#  - les recettes du film (en millions de $)
#
# Et en bonus d'autres informations comme:
# - la note mediane des votes reçus (échelle de 1 à 10)
# - l'écart type des votes reçus

# %% [markdown]
# #### Dataframe contenant des informations concernant chaque acteur et réalisateur présents dans ces films :

# %% [markdown]
# Ce dataframe doit contenir à minima une colonne renseignant:
# - leur nom
# - leur pays de naissance
# - leur age
# - s'il est toujours vivant
# - son/ses métier(s) (a choisir parmi la liste: acteur, realisateur, producteur)
#
# Et en bonus d'autres informations comme:
# - une photo

# %% [markdown]
# ### Réponse 2

# %% [markdown]
# Afficher dans les cellules ci dessous les informations concernant les dataframes

# %%
import sys

class Popularity:
    def __init__(self,film:Film, numberVote, rating:float,income:str) -> None:
        if not  income is None and income != "N/A":
            value = income.split("$")[1].replace(",","")
        else:
            value = 0.00
        self.__film = film
        self.__nbVote = convertStringVote(numberVote)
        self.__rating = round(float(rating),2)
        self.__income = round(float(value),2)
        pass


    ##########################################################
    ######## Calcul de la median face au vote maximal ########
    ##########################################################
    def __median(self, max:int)->float:
        return round(self.__nbVote / max *10,2)

    ##########################################################
    ################# Calcul de l'écart type #################
    ##########################################################
    def __ecartType(self,median)->float:
        return abs(median-float(self.__rating))
    
    def __max(self,listVote):
        max = 0
        for e in listVote : 
            if e> max : 
                max = e
        return max
    
        
    def set_income(self, income:str):
        self.__income = round(income.split("$")[1].replace(",",""),2)

    def get_income(self)->float:
        return self.__income   
    
    def to_dict(self, listVote):
        max = self.__max(listVote)
        median = self.__median(max)
        ecartType = self.__ecartType(median=median)
        return {
            "Film" : self.__film.get_title(),
            "Recette" : self.__income,
            "nombre de vote": self.__nbVote,
            "note moyenne": self.__rating,
            "Note Medianne": median,
            "Ecart Type": ecartType
        }
    
    def getVote(self)->int:
        return self.__nbVote


def getVotes():
    listVote = []
    for p in popularities:
        listVote.append(p.getVote())
    return listVote

def convertStringVote( vote:str)->int:
    vote = vote.replace(",","")
    return int(vote)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Nettoyage des données

# %% [markdown]
# Realisez des opérations de nettoyage des données afin de rendre vos data sets le plus facilement exploitables. Vous réaliserez **a minima** les traitements suivants:
# - convertir les différents types de données rencontrées dans un format adapté pour faciliter les traitements futurs et gagner en RAM
# - vérification et/ou traitement des valeurs manquantes,  des doublons (par exemple des noms identiques, ou écrits avec des orthographes différentes)
# - vérification et traitement des outliers

# %% [markdown]
# ### Réponse 3

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Agrégation et structuration des données

# %% [markdown]
# Vos données étant nettoyées, vous allez maintenant les structurez et les stocker dans un **conteneur de données au format HDF5**. Vous êtes libre d'architecturer votre conteneur comme vous le souhaitez créerez a minima deux groupes:
# - un groupe contenant les images que vous allez acquérir
# - un groupe pour chaque dataset

# %% [markdown]
# ### Réponse 4

# %% [markdown]
# Affichez à minima, des informations concernant chaque groupe ainsi que les data sets qu'ils contient

# %%
import h5py
import numpy as np

with h5py.File('data.hdf5', 'w') as f:
    for col in df.columns:
        f.create_dataset("Cinema/"+col, data=df[col].values)
    for col in df_popularity:
        f.create_dataset("Film/"+col, data=df_popularity[col].values)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Exploitation de vos données
#
# [tutorial HDF5](https://deusyss.developpez.com/tutoriels/Python/hdf5/)

# %% [markdown]
# A partir de votre conteneur de données HDF5 vous allez extraire, filtrer et agréger vos données pour répondre aux questions suivantes:
# - Quelle est la durée médiane des films ?
# - Quels sont les notes moyennes des films par genre ?
# - Faites un graphique pour représenter la répartition des durées des films
# - Quels sont les caractéristiques des films (genre, durée, ...) et acteurs (vivant ou décédé, age, métier, ...),  classés dans les 5% des films les mieux notés ?

# %% [markdown]
# ### Réponse 5

# %% [markdown]
# # Code principal

# %%
response = requests.get('https://www.imdb.com/chart/top/', headers=headers).text
soup = BeautifulSoup(response, 'html.parser')
list = soup.find_all(class_="cli-parent")
films=[]
peoples = []
popularities = []
apiWork = imdbApi()
for l in list:
    film = Film(l.find(class_="ipc-title__text").text.split(" ",1)[1])
    film.set_image(l.find(class_="ipc-image")["src"])
    film_information=l.find(class_="cli-title-metadata").contents
    film.set_year(film_information[0].text)
    film.set_duration(film_information[1].text)
    apiFilm = apiWork.getFilm(name = film.get_title())
    film.set_genre(apiFilm["Genre"])
    film.set_plot(apiFilm["Plot"])
    director = People(apiFilm["Director"],"Réalisateur")
    film.set_director(director)
    if director not in peoples:
        peoples.append(director)
    actors = apiFilm["Actors"].split(", ")
    for a in actors:
        actor = People(a,"Acteur")
        film.add_actors(actor=actor)
        if actor not in peoples:
            peoples.append(actor)
    popularity = Popularity(film=film, numberVote= apiFilm["imdbVotes"], rating=apiFilm["imdbRating"],income=apiFilm["BoxOffice"])
    popularities.append(popularity)
    films.append(film)

df = pd.DataFrame(f.to_dict() for f in films)
df_popularity = pd.DataFrame(p.to_dict(listVote = getVotes()) for p in popularities)

# %%
df
# Out:
#                                                 Image  \
# 0   https://m.media-amazon.com/images/M/MV5BMDAyY2...
# 1   https://m.media-amazon.com/images/M/MV5BYTJkNG...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BNzc1OW...
# 4   https://m.media-amazon.com/images/M/MV5BYjE4Nz...
# 5   https://m.media-amazon.com/images/M/MV5BMTZkMj...
# 6   https://m.media-amazon.com/images/M/MV5BNjM1ZD...
# 7   https://m.media-amazon.com/images/M/MV5BYTViYT...
# 8   https://m.media-amazon.com/images/M/MV5BNzIxMD...
# 9   https://m.media-amazon.com/images/M/MV5BMWM5Zj...
# 10  https://m.media-amazon.com/images/M/MV5BNDYwNz...
# 11  https://m.media-amazon.com/images/M/MV5BMGQxMD...
# 12  https://m.media-amazon.com/images/M/MV5BOTgyOG...
# 13  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 14  https://m.media-amazon.com/images/M/MV5BMTkxNG...
# 15  https://m.media-amazon.com/images/M/MV5BN2NmN2...
# 16  https://m.media-amazon.com/images/M/MV5BN2E5Nz...
# 17  https://m.media-amazon.com/images/M/MV5BYjBkMj...
# 18  https://m.media-amazon.com/images/M/MV5BYzdjMD...
# 19  https://m.media-amazon.com/images/M/MV5BY2IzNz...
# 20  https://m.media-amazon.com/images/M/MV5BMDM4OW...
# 21  https://m.media-amazon.com/images/M/MV5BZjliMW...
# 22  https://m.media-amazon.com/images/M/MV5BNDdhOG...
# 23  https://m.media-amazon.com/images/M/MV5BZGZhZG...
# 24  https://m.media-amazon.com/images/M/MV5BYjY4NG...
#
#                                                 Titre  \
# 0                            The Shawshank Redemption
# 1                                       The Godfather
# 2                                     The Dark Knight
# 3                               The Godfather Part II
# 4                                        12 Angry Men
# 5       The Lord of the Rings: The Return of the King
# 6                                    Schindler's List
# 7                                        Pulp Fiction
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9                      The Good, the Bad and the Ugly
# 10                                       Forrest Gump
# 11              The Lord of the Rings: The Two Towers
# 12                                         Fight Club
# 13                                          Inception
# 14     Star Wars: Episode V - The Empire Strikes Back
# 15                                         The Matrix
# 16                                         Goodfellas
# 17                    One Flew Over the Cuckoo's Nest
# 18                                       Interstellar
# 19                                              Se7en
# 20                              It's a Wonderful Life
# 21                                      Seven Samurai
# 22                           The Silence of the Lambs
# 23                                Saving Private Ryan
# 24                                        City of God
#
#                          Genre Année Duration  \
# 0                        Drama  1994   2h 22m
# 1                 Crime, Drama  1972   2h 55m
# 2         Action, Crime, Drama  2008   2h 32m
# 3                 Crime, Drama  1974   3h 22m
# 4                 Crime, Drama  1957   1h 36m
# 5     Action, Adventure, Drama  2003   3h 21m
# 6    Biography, Drama, History  1993   3h 15m
# 7                 Crime, Drama  1994   2h 34m
# 8     Action, Adventure, Drama  2001   2h 58m
# 9    Adventure, Drama, Western  1966   2h 58m
# 10              Drama, Romance  1994   2h 22m
# 11    Action, Adventure, Drama  2002   2h 59m
# 12                       Drama  1999   2h 19m
# 13   Action, Adventure, Sci-Fi  2010   2h 28m
# 14  Action, Adventure, Fantasy  1980    2h 4m
# 15              Action, Sci-Fi  1999   2h 16m
# 16     Biography, Crime, Drama  1990   2h 25m
# 17                       Drama  1975   2h 13m
# 18    Adventure, Drama, Sci-Fi  2014   2h 49m
# 19       Crime, Drama, Mystery  1995    2h 7m
# 20      Drama, Family, Fantasy  1946   2h 10m
# 21               Action, Drama  1954   3h 27m
# 22      Crime, Drama, Thriller  1991   1h 58m
# 23                  Drama, War  1998   2h 49m
# 24                Crime, Drama  2002   2h 10m
#
#                                           Description  \
# 0   A banker convicted of uxoricide forms a friend...
# 1   The aging patriarch of an organized crime dyna...
# 2   When a menace known as the Joker wreaks havoc ...
# 3   The early life and career of Vito Corleone in ...
# 4   The jury in a New York City murder trial is fr...
# 5   Gandalf and Aragorn lead the World of Men agai...
# 6   In German-occupied Poland during World War II,...
# 7   The lives of two mob hitmen, a boxer, a gangst...
# 8   A meek Hobbit from the Shire and eight compani...
# 9   A bounty hunting scam joins two men in an unea...
# 10  The history of the United States from the 1950...
# 11  While Frodo and Sam edge closer to Mordor with...
# 12  An insomniac office worker and a devil-may-car...
# 13  A thief who steals corporate secrets through t...
# 14  After the Empire overpowers the Rebel Alliance...
# 15  When a beautiful stranger leads computer hacke...
# 16  The story of Henry Hill and his life in the ma...
# 17  In the Fall of 1963, a Korean War veteran and ...
# 18  When Earth becomes uninhabitable in the future...
# 19  Two detectives, a rookie and a veteran, hunt a...
# 20  An angel is sent from Heaven to help a despera...
# 21  Farmers from a village exploited by bandits hi...
# 22  A young F.B.I. cadet must receive the help of ...
# 23  Following the Normandy Landings, a group of U....
# 24  In the slums of Rio, two kids' paths diverge a...
#
#                         Réalisateur  \
# 0                    Frank Darabont
# 1              Francis Ford Coppola
# 2                 Christopher Nolan
# 3              Francis Ford Coppola
# 4                      Sidney Lumet
# 5                     Peter Jackson
# 6                  Steven Spielberg
# 7                 Quentin Tarantino
# 8                     Peter Jackson
# 9                      Sergio Leone
# 10                  Robert Zemeckis
# 11                    Peter Jackson
# 12                    David Fincher
# 13                Christopher Nolan
# 14                   Irvin Kershner
# 15  Lana Wachowski, Lilly Wachowski
# 16                  Martin Scorsese
# 17                     Milos Forman
# 18                Christopher Nolan
# 19                    David Fincher
# 20                      Frank Capra
# 21                   Akira Kurosawa
# 22                   Jonathan Demme
# 23                 Steven Spielberg
# 24   Fernando Meirelles, Kátia Lund
#
#                                                Acteur
# 0     ["Tim Robbins", "Morgan Freeman", "Bob Gunton"]
# 1        ["Marlon Brando", "Al Pacino", "James Caan"]
# 2   ["Christian Bale", "Heath Ledger", "Aaron Eckh...
# 3    ["Al Pacino", "Robert De Niro", "Robert Duvall"]
# 4     ["Henry Fonda", "Lee J. Cobb", "Martin Balsam"]
# 5   ["Elijah Wood", "Viggo Mortensen", "Ian McKell...
# 6    ["Liam Neeson", "Ralph Fiennes", "Ben Kingsley"]
# 7   ["John Travolta", "Uma Thurman", "Samuel L. Ja...
# 8    ["Elijah Wood", "Ian McKellen", "Orlando Bloom"]
# 9   ["Clint Eastwood", "Eli Wallach", "Lee Van Cle...
# 10       ["Tom Hanks", "Robin Wright", "Gary Sinise"]
# 11  ["Elijah Wood", "Ian McKellen", "Viggo Mortens...
# 12        ["Brad Pitt", "Edward Norton", "Meat Loaf"]
# 13  ["Leonardo DiCaprio", "Joseph Gordon-Levitt", ...
# 14  ["Mark Hamill", "Harrison Ford", "Carrie Fisher"]
# 15  ["Keanu Reeves", "Laurence Fishburne", "Carrie...
# 16      ["Robert De Niro", "Ray Liotta", "Joe Pesci"]
# 17  ["Jack Nicholson", "Louise Fletcher", "Michael...
# 18  ["Matthew McConaughey", "Anne Hathaway", "Jess...
# 19    ["Morgan Freeman", "Brad Pitt", "Kevin Spacey"]
# 20  ["James Stewart", "Donna Reed", "Lionel Barrym...
# 21  ["Toshir\u00f4 Mifune", "Takashi Shimura", "Ke...
# 22  ["Jodie Foster", "Anthony Hopkins", "Scott Gle...
# 23        ["Tom Hanks", "Matt Damon", "Tom Sizemore"]
# 24  ["Alexandre Rodrigues", "Leandro Firmino", "Ma...

# %%
df_popularity
# Out:
#                                                  Film      Recette  \
# 0                            The Shawshank Redemption   28767189.0
# 1                                       The Godfather  136381073.0
# 2                                     The Dark Knight  534987076.0
# 3                               The Godfather Part II   47834595.0
# 4                                        12 Angry Men          0.0
# 5       The Lord of the Rings: The Return of the King  381878219.0
# 6                                    Schindler's List   96898818.0
# 7                                        Pulp Fiction  107928762.0
# 8   The Lord of the Rings: The Fellowship of the Ring  319372078.0
# 9                      The Good, the Bad and the Ugly   25100000.0
# 10                                       Forrest Gump  330455270.0
# 11              The Lord of the Rings: The Two Towers  345518923.0
# 12                                         Fight Club   37030102.0
# 13                                          Inception  292587330.0
# 14     Star Wars: Episode V - The Empire Strikes Back  292753960.0
# 15                                         The Matrix  172076928.0
# 16                                         Goodfellas   46909721.0
# 17                    One Flew Over the Cuckoo's Nest  108981275.0
# 18                                       Interstellar  188020017.0
# 19                                              Se7en  100125643.0
# 20                              It's a Wonderful Life    1483643.0
# 21                                      Seven Samurai     800916.0
# 22                           The Silence of the Lambs  130742922.0
# 23                                Saving Private Ryan  217049603.0
# 24                                        City of God    7564459.0
#
#     nombre de vote  note moyenne  Note Medianne  Ecart Type
# 0          2957050           9.3          10.00        0.70
# 1          2057473           9.2           6.96        2.24
# 2          2932729           9.0           9.92        0.92
# 3          1392629           9.0           4.71        4.29
# 4           886741           9.0           3.00        6.00
# 5          2024305           9.0           6.85        2.15
# 6          1480596           9.0           5.01        3.99
# 7          2266472           8.9           7.66        1.24
# 8          2054361           8.9           6.95        1.95
# 9           828737           8.8           2.80        6.00
# 10         2314429           8.8           7.83        0.97
# 11         1819421           8.8           6.15        2.65
# 12         2383262           8.8           8.06        0.74
# 13         2602766           8.8           8.80        0.00
# 14         1405212           8.7           4.75        3.95
# 15         2095617           8.7           7.09        1.61
# 16         1287118           8.7           4.35        4.35
# 17         1088637           8.7           3.68        5.02
# 18         2170072           8.7           7.34        1.36
# 19         1842793           8.6           6.23        2.37
# 20          507065           8.6           1.71        6.89
# 21          373943           8.6           1.26        7.34
# 22         1583062           8.6           5.35        3.25
# 23         1528812           8.6           5.17        3.43
# 24          817002           8.6           2.76        5.84
